# %% [markdown]
# # Backend API Smoke Test\n
# \n
# Start the backend first (`yarn dev` inside `backend`).

# %%
import json
from urllib.request import Request, urlopen
from urllib.error import HTTPError, URLError
from IPython.display import HTML, display

BASE_URL = "http://localhost:3000"

# %%
def get_json(path: str):
    req = Request(f"{BASE_URL}{path}", method="GET")
    try:
        with urlopen(req, timeout=30) as resp:
            body = resp.read().decode("utf-8")
            return resp.status, json.loads(body)
    except HTTPError as e:
        body = e.read().decode("utf-8", errors="replace")
        return e.code, {"error": body}
    except URLError as e:
        return None, {"error": str(e)}

def post_json(path: str, payload: dict):
    data = json.dumps(payload).encode("utf-8")
    req = Request(
        f"{BASE_URL}{path}",
        data=data,
        method="POST",
        headers={"Content-Type": "application/json"},
    )
    try:
        with urlopen(req, timeout=300) as resp:  # 5 minutes
            body = resp.read().decode("utf-8")
            return resp.status, json.loads(body)
    except HTTPError as e:
        body = e.read().decode("utf-8", errors="replace")
        return e.code, {"error": body}
    except URLError as e:
        return None, {"error": str(e)}

# %%
def render_html(html: str, width: int = 800, height: int = 800):
    iframe = f'''<iframe srcdoc="{html.replace(chr(34), '&quot;')}" width="{width}" height="{height}" style="border:1px solid #ccc; border-radius:8px;"></iframe>'''
    display(HTML(iframe))

# %%
# 1) Health check
status, data = get_json("/")
print("status:", status)
print(json.dumps(data, indent=2, ensure_ascii=False))
# Out:
# status: 200
# {
#   "ok": true,
#   "message": "Backend is running"
# }

# %%
status, data = post_json("/ai/gen_engine", {"prompt": "Write one short test sentence."})
print("status:", status)
print(json.dumps(data, indent=2, ensure_ascii=False)[:1500])
# Out:
# status: 200
# {
#   "output": "This is a test sentence."
# }

# %%
payload = {
    "gameDescription": "NEON RONIN — The Cat's Labyrinth — A reimagined Pac-Man set in a cyberpunk Tokyo at night. The character is a robot-ronin chasing a ghost-cat through neon-lit alleyways. The \"ghosts\" are corrupted samurai with movement patterns inspired by Dark Souls bosses. Procedurally generated lo-fi jazz soundtrack. Permadeath (roguelike) with a layout that changes every run. Base: Pac-Man — Theme: Neon Tokyo — Boss: Dark Souls — Audio: Lo-fi jazz — Mechanic: Roguelike",
    "size": 720
}

status, data = post_json("/ai/gen_engine/webgame", payload)
print("status:", status)
if isinstance(data, dict) and "html" in data:
    html = data["html"]
    print("HTML length:", len(html))
    print("Model:", data.get("model"))
    render_html(html, width=760, height=760)

else:
    print(json.dumps(data, indent=2, ensure_ascii=False)[:2000])
# Out:
# status: 200
# HTML length: 30304
# Model: gemini-3.1-pro-preview

# %%
payload = {
    "gameDescription": "Create a simple canvas space shooter that uses this sprite URL: https://example.com/enemy.png",
    "size": 720
}

status, data = post_json("/ai/gen_engine/webgame", payload)
print("status:", status)
if isinstance(data, dict) and "html" in data:
    html = data["html"]
    print("HTML length:", len(html))
    print("Model:", data.get("model"))
    render_html(html, width=760, height=760)

else:
    print(json.dumps(data, indent=2, ensure_ascii=False)[:2000])
# Out:
# status: 200
# HTML length: 10043
# Model: gemini-3.1-pro-preview
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
# <meta charset=&quot;UTF-8&quot;>
# <meta name=&quot;viewport&quot; content=&quot;width=device-width, initial-scale=1.0&quot;>
# <title>Space Shooter</title>
# <style>
#     body {
#         margin: 0;
#         padding: 0;
#         background-color: #1a1a1a;
#         display: flex;
#         justify-content: center;
#         align-items: center;
#         height: 100vh;
#         font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#         overflow: hidden;
#     }
#     canvas {
#         background-color: #050510;
#         width: 720px;
#         height: 720px;
#         box-shadow: 0 0 20px rgba(0, 200, 255, 0.2);
#         border: 2px solid #333;
#     }
# </style>
# </head>
# <body>
# <canvas id=&quot;gameCanvas&quot; width=&quot;720&quot; height=&quot;720&quot;></canvas>
# <script>
#     const canvas = document.getElementById('gameCanvas');
#     const ctx = canvas.getContext('2d');
#
#     // Game State
#     let gameState = 'playing'; // playing, gameover, win
#     let score = 0;
#     const WIN_SCORE = 500;
#     let frameCount = 0;
#
#     // Entities
#     const player = {
#         x: 360 - 25,
#         y: 650,
#         width: 50,
#         height: 50,
#         speed: 7,
#         cooldown: 0
#     };
#
#     let bullets = [];
#     let enemies = [];
#     let stars = [];
#
#     // Initialize Stars
#     for(let i = 0; i < 150; i++) {
#         stars.push({
#             x: Math.random() * canvas.width,
#             y: Math.random() * canvas.height,
#             size: Math.random() * 2 + 1,
#             speed: Math.random() * 3 + 0.5
#         });
#     }
#
#     // Controls
#     const keys = { Left: false, Right: false, Space: false };
#
#     window.addEventListener('keydown', e => {
#         if(['Space', 'ArrowUp', 'ArrowDown', 'ArrowLeft', 'ArrowRight'].includes(e.code)) {
#             e.preventDefault();
#         }
#         if(e.code === 'ArrowLeft' || e.code === 'KeyA') keys.Left = true;
#         if(e.code === 'ArrowRight' || e.code === 'KeyD') keys.Right = true;
#         if(e.code === 'Space') {
#             keys.Space = true;
#             if(gameState !== 'playing') resetGame();
#         }
#     });
#
#     window.addEventListener('keyup', e => {
#         if(e.code === 'ArrowLeft' || e.code === 'KeyA') keys.Left = false;
#         if(e.code === 'ArrowRight' || e.code === 'KeyD') keys.Right = false;
#         if(e.code === 'Space') keys.Space = false;
#     });
#
#     function resetGame() {
#         gameState = 'playing';
#         score = 0;
#         frameCount = 0;
#         bullets = [];
#         enemies = [];
#         player.x = 360 - 25;
#     }
#
#     function checkCollision(rect1, rect2) {
#         return (rect1.x < rect2.x + rect2.width &&
#                 rect1.x + rect1.width > rect2.x &&
#                 rect1.y < rect2.y + rect2.height &&
#                 rect1.y + rect1.height > rect2.y);
#     }
#
#     function update() {
#         // Update Stars
#         stars.forEach(star => {
#             star.y += star.speed;
#             if(star.y > canvas.height) {
#                 star.y = 0;
#                 star.x = Math.random() * canvas.width;
#             }
#         });
#
#         if (gameState === 'playing') {
#             frameCount++;
#
#             // Player Movement
#             if (keys.Left) player.x -= player.speed;
#             if (keys.Right) player.x += player.speed;
#
#             // Constrain to canvas
#             if (player.x < 0) player.x = 0;
#             if (player.x + player.width > canvas.width) player.x = canvas.width - player.width;
#
#             // Shooting
#             if (player.cooldown > 0) player.cooldown--;
#             if (keys.Space && player.cooldown === 0) {
#                 bullets.push({
#                     x: player.x + player.width / 2 - 4,
#                     y: player.y,
#                     width: 8,
#                     height: 18,
#                     speed: 12
#                 });
#                 player.cooldown = 15;
#             }
#
#             // Update Bullets
#             for (let i = bullets.length - 1; i >= 0; i--) {
#                 bullets[i].y -= bullets[i].speed;
#                 if (bullets[i].y < -20) bullets.splice(i, 1);
#             }
#
#             // Spawn Enemies
#             let spawnInterval = Math.max(25, 60 - Math.floor(score / 20));
#             if (frameCount % spawnInterval === 0) {
#                 let size = 45;
#                 enemies.push({
#                     x: Math.random() * (canvas.width - size),
#                     y: -size,
#                     width: size,
#                     height: size,
#                     speed: 2 + Math.random() * 2 + (score / 200)
#                 });
#             }
#
#             // Update Enemies & Collisions
#             for (let i = enemies.length - 1; i >= 0; i--) {
#                 let e = enemies[i];
#                 e.y += e.speed;
#
#                 // Game Over if enemy reaches bottom
#                 if (e.y > canvas.height) {
#                     gameState = 'gameover';
#                 }
#
#                 // Game Over if enemy touches player
#                 if (checkCollision(player, e)) {
#                     gameState = 'gameover';
#                 }
#
#                 // Check bullet collisions
#                 let enemyHit = false;
#                 for (let j = bullets.length - 1; j >= 0; j--) {
#                     let b = bullets[j];
#                     if (checkCollision(b, e)) {
#                         bullets.splice(j, 1);
#                         enemyHit = true;
#                         break;
#                     }
#                 }
#
#                 if (enemyHit) {
#                     enemies.splice(i, 1);
#                     score += 10;
#                     if (score >= WIN_SCORE) {
#                         gameState = 'win';
#                     }
#                 }
#             }
#         }
#     }
#
#     function draw() {
#         // Clear Canvas
#         ctx.clearRect(0, 0, canvas.width, canvas.height);
#
#         // Draw Stars
#         ctx.fillStyle = '#ffffff';
#         stars.forEach(star => {
#             ctx.globalAlpha = star.size / 3;
#             ctx.fillRect(star.x, star.y, star.size, star.size);
#         });
#         ctx.globalAlpha = 1.0;
#
#         // Draw Player (Spaceship)
#         ctx.fillStyle = '#00f0ff';
#         ctx.beginPath();
#         ctx.moveTo(player.x + player.width / 2, player.y); // Nose
#         ctx.lineTo(player.x + player.width, player.y + player.height); // Right wing
#         ctx.lineTo(player.x + player.width / 2, player.y + player.height - 10); // Engine indent
#         ctx.lineTo(player.x, player.y + player.height); // Left wing
#         ctx.closePath();
#         ctx.fill();
#
#         // Engine flame
#         if (keys.Left || keys.Right || keys.Space || frameCount % 10 < 5) {
#             ctx.fillStyle = '#ff9900';
#             ctx.beginPath();
#             ctx.moveTo(player.x + player.width / 2 - 10, player.y + player.height - 5);
#             ctx.lineTo(player.x + player.width / 2 + 10, player.y + player.height - 5);
#             ctx.lineTo(player.x + player.width / 2, player.y + player.height + 15);
#             ctx.closePath();
#             ctx.fill();
#         }
#
#         // Draw Bullets
#         ctx.fillStyle = '#ff0055';
#         bullets.forEach(b => {
#             ctx.shadowBlur = 10;
#             ctx.shadowColor = '#ff0055';
#             ctx.fillRect(b.x, b.y, b.width, b.height);
#             ctx.shadowBlur = 0;
#         });
#
#         // Draw Enemies
#         enemies.forEach(e => {
#             // Graphic drawn with canvas methods
#             ctx.fillStyle = '#a00000';
#             ctx.fillRect(e.x, e.y, e.width, e.height);
#             ctx.fillStyle = '#ff0000';
#             ctx.fillRect(e.x + 5, e.y + 5, e.width - 10, e.height - 10);
#             // Eyes
#             ctx.fillStyle = '#0ff';
#             ctx.fillRect(e.x + 10, e.y + 15, 8, 8);
#             ctx.fillRect(e.x + e.width - 18, e.y + 15, 8, 8);
#         });
#
#         // Draw UI
#         ctx.fillStyle = '#ffffff';
#         ctx.font = 'bold 24px sans-serif';
#         ctx.textAlign = 'left';
#         ctx.fillText(`SCORE: ${score} / ${WIN_SCORE}`, 20, 40);
#
#         // Dra

# %%
# load test_prompt.txt
with open("test_prompt.txt", "r") as f:
    long_prompt = f.read()

payload = {
    "gameDescription": long_prompt,
    "size": 720
}

status, data = post_json("/ai/gen_engine/webgame", payload)
print("status:", status)
if isinstance(data, dict) and "html" in data:
    html = data["html"]
    print("HTML length:", len(html))
    print("Model:", data.get("model"))


else:
    print(json.dumps(data, indent=2, ensure_ascii=False)[:2000])
# Out:
# status: 504
# {
#   "error": "{\"error\":\"Webgame validation timed out\",\"traceId\":\"844e888a-8f20-4f12-bd3f-0e13d78fba0f\",\"timeoutMs\":180000,\"phase\":\"generation_started\",\"hint\":\"Increase GEN_ENGINE_TOTAL_TIMEOUT_MS for larger generations.\"}"
# }

# %%
render_html(html, width=760, height=760)
# Out:
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
# <head>
# <meta charset=&quot;UTF-8&quot;>
# <title>Inferno Drift</title>
# <style>
#     body {
#         margin: 0;
#         padding: 0;
#         background-color: #000;
#         display: flex;
#         justify-content: center;
#         align-items: center;
#         height: 100vh;
#         overflow: hidden;
#         font-family: 'Courier New', Courier, monospace;
#         color: #fff;
#         user-select: none;
#     }
#     canvas {
#         background-color: #050505;
#         box-shadow: 0 0 40px #ff3300, inset 0 0 20px #000;
#         border: 2px solid #331100;
#         cursor: crosshair;
#     }
# </style>
# </head>
# <body>
# <canvas id=&quot;gameCanvas&quot; width=&quot;720&quot; height=&quot;720&quot;></canvas>
# <script>
#     const canvas = document.getElementById('gameCanvas');
#     const ctx = canvas.getContext('2d');
#     const W = 720, H = 720;
#
#     // Game State
#     let state = 'MENU'; // MENU, PLAY, OVER, WIN
#     let score = 0;
#     let distance = 0;
#     let multiplier = 1;
#     let cameraY = 0;
#     let flashAlpha = 0;
#     let screenShake = 0;
#
#     // Track Configuration
#     const TRACK_BASE_W = 220;
#     const SKIM_ZONE = 30;
#     const WIN_DISTANCE = 30000;
#
#     // Entities
#     let player = {};
#     let particles = [];
#     let bullets = [];
#     let asteroids = [];
#     let ash = [];
#
#     // Eruption State
#     let eruptionTimer = 0;
#     let eruptionActive = false;
#     let eruptionDuration = 0;
#
#     // Input
#     const keys = { ArrowUp: false, ArrowLeft: false, ArrowRight: false, ArrowDown: false, Shift: false, ' ': false };
#     let lastShoot = 0;
#
#     window.addEventListener('keydown', e => {
#         if(keys.hasOwnProperty(e.key) || e.key === ' ') keys[e.key] = true;
#         if(e.key === ' ' && (state === 'MENU' || state === 'OVER' || state === 'WIN')) resetGame();
#     });
#     window.addEventListener('keyup', e => {
#         if(keys.hasOwnProperty(e.key) || e.key === ' ') keys[e.key] = false;
#     });
#
#     function initPlayer() {
#         player = {
#             x: W / 2, y: 100,
#             vx: 0, vy: 0,
#             angle: Math.PI / 2,
#             health: 100, maxHealth: 100,
#             boost: 0, maxBoost: 100,
#             radius: 12
#         };
#     }
#
#     function resetGame() {
#         initPlayer();
#         score = 0;
#         distance = 0;
#         multiplier = 1;
#         cameraY = 0;
#         particles = [];
#         bullets = [];
#         asteroids = [];
#         eruptionTimer = 600;
#         eruptionActive = false;
#         state = 'PLAY';
#         flashAlpha = 1;
#
#         // Init Ash
#         ash = [];
#         for(let i=0; i<100; i++) {
#             ash.push({
#                 x: Math.random() * W, y: Math.random() * H,
#                 s: Math.random() * 2 + 1, v: Math.random() * 2 + 1
#             });
#         }
#     }
#
#     // Procedural Track Generation
#     function getTrackCenter(y) {
#         let n1 = Math.sin(y * 0.002) * 180;
#         let n2 = Math.sin(y * 0.005) * 60;
#         let n3 = Math.cos(y * 0.01) * 30;
#         return W / 2 + n1 + n2 + n3;
#     }
#
#     function spawnParticle(x, y, vx, vy, life, color, size) {
#         particles.push({ x, y, vx, vy, life, maxLife: life, color, size });
#     }
#
#     function spawnAsteroid() {
#         let numVerts = 7 + Math.floor(Math.random() * 5);
#         let radius = 20 + Math.random() * 30;
#         let verts = [];
#         for(let i=0; i<numVerts; i++) {
#             let a = (i / numVerts) * Math.PI * 2;
#             let r = radius * (0.7 + Math.random() * 0.3);
#             verts.push({x: Math.cos(a)*r, y: Math.sin(a)*r});
#         }
#         asteroids.push({
#             x: W/2 + (Math.random()-0.5)*W,
#             y: cameraY - 100,
#             vx: (Math.random()-0.5) * 3,
#             vy: 2 + Math.random() * 4,
#             av: (Math.random()-0.5) * 0.2,
#             angle: 0,
#             r: radius,
#             verts: verts,
#             hp: radius
#         });
#     }
#
#     function update() {
#         if (state !== 'PLAY') return;
#
#         let prevY = player.y;
#
#         // Player Controls (Newtonian Thrust & Drift)
#         if (keys.ArrowLeft) player.angle -= 0.08;
#         if (keys.ArrowRight) player.angle += 0.08;
#
#         let thrustPower = 0;
#         if (keys.ArrowUp) {
#             let power = 0.4;
#             if (keys.Shift && player.boost > 0) {
#                 power = 0.9;
#                 player.boost -= 1.5;
#                 screenShake = 2;
#                 spawnParticle(player.x - Math.cos(player.angle)*15, player.y - Math.sin(player.angle)*15, (Math.random()-0.5)*2, (Math.random()-0.5)*2 + 2, 20, '#0ff', 4);
#             }
#             player.vx += Math.cos(player.angle) * power;
#             player.vy += Math.sin(player.angle) * power;
#
#             // Engine flame particles
#             spawnParticle(player.x - Math.cos(player.angle)*15, player.y - Math.sin(player.angle)*15, player.vx*-0.2 + (Math.random()-0.5)*2, player.vy*-0.2 + (Math.random()-0.5)*2, 15, '#fa0', 3);
#         }
#         if (keys.ArrowDown) {
#             player.vx *= 0.95;
#             player.vy *= 0.95;
#         }
#
#         // Shooting
#         if (keys[' '] && Date.now() - lastShoot > 150) {
#             bullets.push({
#                 x: player.x + Math.cos(player.angle)*15,
#                 y: player.y + Math.sin(player.angle)*15,
#                 vx: player.vx + Math.cos(player.angle)*15,
#                 vy: player.vy + Math.sin(player.angle)*15,
#                 life: 60
#             });
#             lastShoot = Date.now();
#         }
#
#         // Gravity & Physics
#         player.vy += 0.15; // Constant pull down the volcano
#         player.vx *= 0.98; // Drift friction
#         player.vy *= 0.98;
#
#         player.x += player.vx;
#         player.y += player.vy;
#
#         // Track Collision & Magma Skim
#         let cx = getTrackCenter(player.y);
#         let distFromCenter = Math.abs(player.x - cx);
#         let halfTrack = TRACK_BASE_W / 2;
#
#         multiplier = 1;
#         if (distFromCenter > halfTrack - SKIM_ZONE) {
#             if (distFromCenter < halfTrack + 10) {
#                 // Magma Skim - Risk/Reward
#                 player.boost = Math.min(player.maxBoost, player.boost + 1);
#                 multiplier = 5;
#                 score += 2;
#                 spawnParticle(player.x, player.y, (Math.random()-0.5)*5, -Math.random()*5, 20, '#fff', 2);
#                 if(Math.random()<0.2) spawnParticle(player.x, player.y, (Math.random()-0.5)*5, -Math.random()*5, 30, '#0ff', 3);
#             } else {
#                 // In Lava - Damage
#                 player.health -= 1.5;
#                 screenShake = 5;
#                 spawnParticle(player.x, player.y, (Math.random()-0.5)*10, -Math.random()*10, 40, '#f00', 5);
#             }
#         }
#
#         // Walls (Hard limit so player doesn't fly infinitely away)
#         if (distFromCenter > halfTrack + 150) {
#             player.health -= 5;
#         }
#
#         // Progress
#         if (player.y > prevY) distance = Math.max(distance, player.y);
#         score += (player.y > prevY ? (player.y - prevY)*0.1 * multiplier : 0);
#
#         // Camera follow
#         cameraY = player.y - H * 0.3;
#
#         // Eruption Logic
#         eruptionTimer--;
#         if (eruptionTimer <= 0 && !eruptionActive) {
#             eruptionActive = true;
#             eruptionDuration = 300 + Math.random() * 200;
#             flashAlpha = 1;
#         }
#
#         if (eruptionActive) {
#             eruptionDuration--;
#             screenShake = 4;
#             if (Math.random() < 0.08) spawnAsteroid();
#             if (eruptionDuration <= 0) {
#                 eruptionActive = false;
#                 eruptionTimer = 500 + Math.random() * 500;
#             }
#         }
#
#         // Update Bullets
#         for (let i = bullets.length - 1; i >= 0; i--) {
#             let b = bullets[i];
#             b.x += b.vx; b.y += b.vy; b.life--;
#             if (b.life <= 0) bullets.splice(i, 1);
#         }
#
#         // Update Asteroids & Collisions
#         for (let i = asteroids.length - 1; i >= 0; i--) {
#             let a = asteroids[i];
#             a.x += a.v
